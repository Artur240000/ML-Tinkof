# %%
import matplotlib.pyplot as plt
import sklearn
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
x=[1,3,2,4,5,5,6,8,7,9]
y=[2,1,3,4,4,2,3,7,4,6]
len(y)
# Out:
# 10

# %%
for i in range(10):
    print("(",y[i],-x[i],'K',")")
# Out:
# ( 2 -1 K )
# ( 1 -3 K )
# ( 3 -2 K )
# ( 4 -4 K )
# ( 4 -5 K )
# ( 2 -5 K )
# ( 3 -6 K )
# ( 7 -8 K )
# ( 4 -7 K )
# ( 6 -9 K )

# %%
plt.plot(x,y)
plt.plot(x,x)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
al=np.linspace(0.0001, 7, 30)
def line(k):
    return  k*x

# %%
for i in range(len(al)):
    y_pred=[]
    for k in range(10):
        yi=al[i]*x[k]
        y_pred.append(yi)
    print(mean_squared_error(y, y_pred), al[i])
# Out:
# 15.995740310000002 0.0001
# 7.52075662668252 0.2414758620689655
# 2.65803596431629 0.48285172413793104
# 1.407578322901308 0.7242275862068965
# 3.769383702437574 0.9656034482758621
# 9.74345210292509 1.2069793103448276
# 19.32978352436385 1.448355172413793
# 32.528377966753865 1.6897310344827587
# 49.33923543009513 1.9311068965517242
# 69.76235591438765 2.17248275862069
# 93.79773941963143 2.4138586206896555
# 121.44538594582646 2.655234482758621
# 152.70529549297265 2.8966103448275864
# 187.5774680610702 3.137986206896552
# 226.06190365011898 3.3793620689655177
# 268.1586022601189 3.620737931034483
# 313.86756389107023 3.8621137931034486
# 363.18878854297265 4.103489655172414
# 416.12227621582633 4.344865517241379
# 472.6680269096315 4.586241379310345
# 532.8260406243877 4.82761724137931
# 596.5963173600951 5.068993103448276
# 663.9788571167539 5.310368965517242
# 734.9736598943639 5.551744827586207
# 809.580725692925 5.793120689655172
# 887.8000545124376 6.034496551724138
# ...

# %%
new=np.linspace(0.48285172413793104, 0.9656034482758621, 40)

# %%
for i in range(len(new)):
    y_pred_new=[]
    for k in range(10):
        yi=new[i]*x[k]
        y_pred_new.append(yi)
    print(mean_squared_error(y, y_pred_new), new[i])
# Out:
# 2.65803596431629 0.48285172413793104
# 2.506037655436891 0.4952299734748011
# 2.363539052069529 0.5076082228116711
# 2.2305401542142 0.5199864721485411
# 2.107040961870906 0.5323647214854111
# 1.9930414750396472 0.5447429708222812
# 1.8885416937204227 0.5571212201591512
# 1.793541617913234 0.5694994694960213
# 1.7080412476180786 0.5818777188328913
# 1.63204058283496 0.5942559681697612
# 1.5655396235638754 0.6066342175066313
# 1.5085383698048254 0.6190124668435013
# 1.4610368215578102 0.6313907161803713
# 1.4230349788228298 0.6437689655172414
# 1.3945328415998846 0.6561472148541114
# 1.375530409888974 0.6685254641909815
# 1.3660276836900984 0.6809037135278515
# 1.3660246630032575 0.6932819628647215
# 1.3755213478284518 0.7056602122015916
# 1.3945177381656806 0.7180384615384616
# 1.4230138340149443 0.7304167108753316
# 1.4610096353762427 0.7427949602122016
# 1.5085051422495763 0.7551732095490716
# 1.5655003546349442 0.7675514588859417
# 1.6319952725323479 0.7799297082228117
# ...

# %%
n=np.linspace(0.6809037135278515, 0.7056602122015916, 40)

# %%
for i in range(len(n)):
    y_pred_n=[]
    for k in range(10):
        yi=n[i]*x[k]
        y_pred_n.append(yi)
    print(mean_squared_error(y, y_pred_n), n[i])
# Out:
# 1.3660276836900984 0.6809037135278515
# 1.3657964379849579 0.6815384955451269
# 1.3655901750688035 0.6821732775624023
# 1.3654088949416354 0.6828080595796777
# 1.3652525976034535 0.683442841596953
# 1.3651212830542583 0.6840776236142284
# 1.365014951294049 0.6847124056315038
# 1.364933602322826 0.6853471876487792
# 1.3648772361405896 0.6859819696660546
# 1.364845852747339 0.68661675168333
# 1.364839452143075 0.6872515337006053
# 1.3648580343277974 0.6878863157178807
# 1.364901599301506 0.6885210977351561
# 1.3649701470642008 0.6891558797524315
# 1.365063677615882 0.6897906617697069
# 1.365182190956549 0.6904254437869823
# 1.365325687086203 0.6910602258042577
# 1.3654941660048427 0.691695007821533
# 1.365687627712469 0.6923297898388084
# 1.3659060722090817 0.6929645718560838
# 1.3661494994946803 0.6935993538733592
# 1.3664179095692655 0.6942341358906347
# 1.3667113024328368 0.69486891790791
# 1.3670296780853943 0.6955036999251853
# 1.3673730365269383 0.6961384819424608
# ...

# %%
k_best=0.6872515337006053
y_best=[]
y_best_2=[]
k_best_2=213/310
for i in range(10):
    y_best.append(k_best*x[i])
    y_best_2.append(k_best_2*x[i])
plt.plot(x,y)
plt.plot(x,y_best)
plt.plot(x, y_best_2)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
c,d=0,0
for i in range(10):
    c+=y_best[i]
    d+=y_best_2[i]
print(c,d)
# Out:
# 34.36257668503026 34.35483870967742

# %%
y
# Out:
# [2, 1, 3, 4, 4, 2, 3, 7, 4, 6]

# %%
plt.plot(x,y)
plt.plot(x,y_best)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(x,y)
plt.plot(x,y_best_2)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(x,y_best_2)
plt.plot(x,y_best)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
